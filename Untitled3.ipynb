# %% [markdown]
# <a href="https://colab.research.google.com/github/husickova/keboola/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# !pip install torch
# !pip install sentence_transformers
# !pip install faiss-cpu
# !pip install huggingface-hub
# !pip install pypdf
# !pip -q install accelerate
# !pip install llama-cpp-python
# !pip -q install git+https://github.com/huggingface/transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.6/274.6 kB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 14.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 43.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 61.8 MB/s eta 0:00:00
# ...

# %%
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.llms import LlamaCpp
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.document_loaders import TextLoader, DirectoryLoader
import os

# %%
directory_path = "/content/drive/MyDrive/Keboola"
loader = DirectoryLoader(directory_path, glob="**/*.txt", loader_cls=TextLoader, silent_errors=True)
data = loader.load()

# %%
#Step 05: Split the Extracted Data into Text Chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=10000, chunk_overlap=20)
text_chunks = text_splitter.split_documents(data)

# %%
#Step 06:Downlaod the Embeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
#Step 08: Create Embeddings for each of the Text Chunk
vector_store = FAISS.from_documents(text_chunks, embedding=embeddings)

# %%
#Import Model
llm = LlamaCpp(
    streaming = True,
    model_path="/content/drive/MyDrive/model_mistral/mistral-7b-instruct-v0.2.Q5_K_S.gguf",
    temperature=0.75,
    top_p=1,
    verbose=True,
    n_ctx=4096
)

# %%
qa = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=vector_store.as_retriever(search_kwargs={"k": 5}))

# %%
query = "Based on the information you have, who would be strong candidates for open positions at Keboola and why?"

# %%
qa.invoke(query)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
#
# llama_print_timings:        load time =    1326.53 ms
# llama_print_timings:      sample time =       1.19 ms /     2 runs   (    0.60 ms per token,  1676.45 tokens per second)
# llama_print_timings: prompt eval time =   95722.32 ms /   739 tokens (  129.53 ms per token,     7.72 tokens per second)
# llama_print_timings:        eval time =     190.19 ms /     1 runs   (  190.19 ms per token,     5.26 tokens per second)
# llama_print_timings:       total time =   96154.39 ms /   740 tokens
# 'isión'

# %%
import sys

while True:
  user_input = input(f"Input Prompt: ")
  if user_input == 'exit':
    print('Exiting')
    sys.exit()
  if user_input == '':
    continue
  result = qa({'query': user_input})
  print(f"Answer: {result['result']}")
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    1326.53 ms
# llama_print_timings:      sample time =     137.29 ms /   256 runs   (    0.54 ms per token,  1864.63 tokens per second)
# llama_print_timings: prompt eval time =   80673.94 ms /   683 tokens (  118.12 ms per token,     8.47 tokens per second)
# llama_print_timings:        eval time =   46242.96 ms /   255 runs   (  181.34 ms per token,     5.51 tokens per second)
# llama_print_timings:       total time =  128154.23 ms /   938 tokens
# Answer: isión en un sistema de procesamiento de datos en la nube basado en Keboola. La candidatura ideal de Keboola posee una combinación única de habilidades técnicas, habilidades de resolución de problemas y un entendimiento de cómo el dato puede conducir el valor de negocio. Vamos a examinar algunos perfiles clave que resaltan las calificaciones que Keboola busca en sus miembros de equipo.
#
# ...
